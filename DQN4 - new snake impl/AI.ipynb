# %%
""" https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
https://user.ceng.metu.edu.tr/~emre/resources/courses/AdvancedDL_Spring2017/DQN_Muhammed.pdf
https://www.youtube.com/watch?v=NP8pXZdU-5U&t=1s """
import matplotlib.pyplot as plt
import torch
import numpy as np
from copy import deepcopy
from tqdm import tqdm
from SnakeEnvironment import *
from Agent import *
import collections
import random
from itertools import count
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# TRY:
# - Longer training
# - More layers in NN
# - Bigger layers in NN
# - Different loss

# %%
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.0
EPS_DECAY = 0.00001
TARGET_UPDATE = 50
MY_SEED = 143
LR = 0.0001
MEMORY_SIZE = 1000000
# Get screen size so that we can initialize layers correctly based on shape
# returned from AI gym. Typical dimensions at this point are close to 3x40x90
# which is the result of a clamped and down-scaled render buffer in get_screen()
state_size = 16
nr_actions = 4

agent_007 = Agent(gamma=GAMMA,exploration_rate=EPS_START,lr=LR,
                  input_size=state_size, batch_size=BATCH_SIZE,
                  nr_actions=nr_actions, max_mem_size=MEMORY_SIZE,
                  nr_consecutive_frames=1, exploration_rate_min=EPS_END,
                  exploration_decay_rate=EPS_DECAY,seed=MY_SEED)

# %%
NUM_EPISODES = 2500

episode_durations = []
episode_rewards = []
episode_exploration_rates = []

t_total_counter = 0
for i_episode in tqdm(range(NUM_EPISODES)):
    # Initialize the environment and state
    game_env = SnakeEnvironment(seed=MY_SEED + i_episode,  # Try both constant seed and varying seed for each episode
                                display_gameplay=False)
    game_env.initialize_environment()

    current_game_score = 0
    current_game_duration = 0

    current_exploration_rate = 0
    current_steps_counter = 0
    game_over = False
    current_state = game_env.get_state()

    for t in count():
        # Select and perform an action according to greedy epsilon strategy
        action = agent_007.choose_action(current_state)

        # Perform action in game environment and observe reward and new state + termination flag.
        reward, game_over, new_observation = game_env.step(action)
        current_game_score += reward
        reward = torch.tensor([reward])

        # Observe new state
        last_state = current_state
        current_state = new_observation

        # Store the transition in memory
        # print(type(last_state), type(action),type(reward),type(current_state),type(game_over))
        agent_007.store_transition(state=last_state,action=action,
                                   reward=reward,new_state=current_state,
                                   done_flag=game_over)



        # Perform one step of the optimization (on the policy network)
        agent_007.learn()
        if game_over:
            break
        t_total_counter += 1
        current_game_duration += 1

        # Update the target network, copying all weights and biases in DQN from policy to target network
        if t % TARGET_UPDATE == 0:
            agent_007.align_networks()

    episode_rewards.append(current_game_score)
    episode_durations.append(current_game_duration)
    episode_exploration_rates.append(agent_007.exploration_rate)
# Out:
#  47%|████▋     | 1662/3500 [00:59<01:05, 27.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 44
#      37 agent_007.store_transition(state=last_state,action=action,
#      38                            reward=reward,new_state=current_state,
#      39                            done_flag=game_over)
#      43 # Perform one step of the optimization (on the policy network)
# ---> 44 agent_007.learn()
#      45 if game_over:
#      46     break
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/DQN4 - new snake impl/Agent.py:136, in Agent.learn(self)
#     133 target_q_values[terminal_batch] = 0.0
#     135 # Calculating all Q values
# --> 136 q_values = self.policy_network(state_batch)
#     138 # Taking out the ones corresponding to the action taken
#     139 q_values = torch.gather(input=q_values, dim=1, index=action_batch)
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/DQN4 - new snake impl/NeuralNet.py:31, in DeepQNetwork.forward(self, state)
#      29 def forward(self, state: torch.Tensor) -> torch.Tensor:
#      30     state = state.to(self.device)
# ---> 31     state = self.rectifier(self.lin1(state))
#      32     state = self.lin2(state)
#      33     return state
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot([i for i in range(len(episode_rewards))], episode_rewards)
ax[1].plot([i for i in range(len(episode_durations))], episode_durations)
ax[2].plot([i for i in range(len(episode_exploration_rates))], episode_exploration_rates)
plt.show()

# %%
avg_period = NUM_EPISODES//100
avg_episode_rewards, avg_episode_durations, avg_episode_exploration_rates = [], [], []
for period in range(0, len(episode_rewards) // avg_period):
    avg_episode_rewards.append(np.mean(episode_rewards[avg_period * period : avg_period * (period + 1)]))
    avg_episode_durations.append(np.mean(episode_durations[avg_period * period : avg_period * (period + 1)]))
    avg_episode_exploration_rates.append(np.mean(episode_exploration_rates[avg_period * period : avg_period * (period + 1)]))

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot([ i for i in range(len(avg_episode_rewards))], avg_episode_rewards)
ax[1].plot([ i for i in range(len(avg_episode_durations))], avg_episode_durations)
ax[2].plot([ i for i in range(len(avg_episode_exploration_rates))], avg_episode_exploration_rates)
plt.show()

# %%
Play_game = True
if Play_game:
    game_env = SnakeEnvironment(seed=1,  # Try both constant seed and varying seed for each episode
                                neural_net=agent_007.policy_network,
                                display_gameplay=True,
                                graphics_speed=4)
    game_env.run()
# Out:
# break out counter:  0
# current_action_index:  3
# break out counter:  1
# current_action_index:  1
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  1
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  1
# current_action_index:  1
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  2
# break out counter:  19
# current_action_index:  2
# break out counter:  20
# current_action_index:  2
# break out counter:  21
# current_action_index:  2
# break out counter:  22
# current_action_index:  2
# break out counter:  23
# current_action_index:  2
# break out counter:  24
# current_action_index:  2
# break out counter:  25
# current_action_index:  2
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  2
# break out counter:  19
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  2
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  2
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  1
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  1
# current_action_index:  1
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  1
# break out counter:  6
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  0
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  2
# break out counter:  20
# current_action_index:  2
# break out counter:  21
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  1
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  0
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  0
# break out counter:  19
# current_action_index:  0
# break out counter:  20
# current_action_index:  0
# break out counter:  21
# current_action_index:  0
# break out counter:  22
# current_action_index:  0
# break out counter:  23
# current_action_index:  0
# break out counter:  24
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  1
# break out counter:  5
# current_action_index:  1
# break out counter:  6
# current_action_index:  1
# break out counter:  7
# current_action_index:  1
# break out counter:  8
# current_action_index:  1
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  1
# break out counter:  5
# current_action_index:  1
# break out counter:  6
# current_action_index:  1
# break out counter:  7
# current_action_index:  1
# break out counter:  8
# current_action_index:  1
# break out counter:  9
# current_action_index:  1
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  2
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  2
# break out counter:  19
# current_action_index:  2
# break out counter:  1
# current_action_index:  1
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  1
# break out counter:  25
# current_action_index:  1
# break out counter:  26
# current_action_index:  1
# break out counter:  27
# current_action_index:  1
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  2
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  1
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  0
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  0
# break out counter:  19
# current_action_index:  0
# break out counter:  20
# current_action_index:  0
# break out counter:  21
# current_action_index:  0
# break out counter:  22
# current_action_index:  0
# break out counter:  23
# current_action_index:  0
# break out counter:  24
# current_action_index:  0
# break out counter:  25
# current_action_index:  0
# break out counter:  26
# current_action_index:  0
# break out counter:  27
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  3
# break out counter:  25
# current_action_index:  3
# break out counter:  26
# current_action_index:  3
# break out counter:  27
# current_action_index:  3
# break out counter:  28
# current_action_index:  3
# break out counter:  29
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  2
# break out counter:  19
# current_action_index:  2
# break out counter:  20
# current_action_index:  2
# break out counter:  21
# current_action_index:  2
# break out counter:  22
# current_action_index:  2
# break out counter:  23
# current_action_index:  2
# break out counter:  24
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  1
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  2
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  2
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  1
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  1
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  1
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  0
# break out counter:  19
# current_action_index:  0
# break out counter:  20
# current_action_index:  0
# break out counter:  21
# current_action_index:  0
# break out counter:  22
# current_action_index:  0
# break out counter:  23
# current_action_index:  2
# break out counter:  24
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  1
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  0
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  3
# break out counter:  25
# current_action_index:  3
# break out counter:  26
# current_action_index:  3
# break out counter:  27
# current_action_index:  3
# break out counter:  28
# current_action_index:  3
# break out counter:  29
# current_action_index:  3
# break out counter:  30
# current_action_index:  3
# break out counter:  31
# current_action_index:  3
# break out counter:  32
# current_action_index:  3
# break out counter:  33
# current_action_index:  3
# break out counter:  34
# current_action_index:  3
# break out counter:  35
# current_action_index:  3
# break out counter:  36
# current_action_index:  1
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  0
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  2
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  3
# break out counter:  25
# current_action_index:  3
# break out counter:  26
# current_action_index:  3
# break out counter:  27
# current_action_index:  3
# break out counter:  28
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  3
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  1
# break out counter:  25
# current_action_index:  2
# break out counter:  26
# current_action_index:  1
# break out counter:  27
# current_action_index:  3
# break out counter:  28
# current_action_index:  1
# break out counter:  29
# current_action_index:  3
# break out counter:  30
# current_action_index:  1
# break out counter:  31
# current_action_index:  3
# break out counter:  32
# current_action_index:  0
# break out counter:  33
# current_action_index:  3
# break out counter:  34
# current_action_index:  0
# break out counter:  35
# current_action_index:  3
# break out counter:  36
# current_action_index:  1
# break out counter:  37
# current_action_index:  3
# break out counter:  38
# current_action_index:  0
# break out counter:  39
# current_action_index:  3
# break out counter:  40
# current_action_index:  0
# break out counter:  41
# current_action_index:  3
# break out counter:  42
# current_action_index:  3
# break out counter:  43
# current_action_index:  3
# break out counter:  44
# current_action_index:  3
# break out counter:  45
# current_action_index:  3
# break out counter:  46
# current_action_index:  2
# break out counter:  47
# current_action_index:  2
# break out counter:  48
# current_action_index:  2
# break out counter:  49
# current_action_index:  2
# break out counter:  50
# current_action_index:  2
# break out counter:  51
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  2
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  1
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  3
# break out counter:  1
# current_action_index:  1
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  2
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  2
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  0
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  2
# break out counter:  7
# current_action_index:  3
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  3
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  3
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  3
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  3
# break out counter:  5
# current_action_index:  3
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  3
# break out counter:  9
# current_action_index:  1
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  3
# break out counter:  13
# current_action_index:  1
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  1
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  0
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  1
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  0
# break out counter:  24
# current_action_index:  3
# break out counter:  25
# current_action_index:  1
# break out counter:  26
# current_action_index:  1
# break out counter:  27
# current_action_index:  0
# break out counter:  28
# current_action_index:  0
# break out counter:  29
# current_action_index:  0
# break out counter:  30
# current_action_index:  0
# break out counter:  31
# current_action_index:  0
# break out counter:  32
# current_action_index:  0
# break out counter:  33
# current_action_index:  2
# break out counter:  34
# current_action_index:  3
# break out counter:  35
# current_action_index:  3
# break out counter:  36
# current_action_index:  3
# break out counter:  37
# current_action_index:  3
# break out counter:  38
# current_action_index:  3
# break out counter:  39
# current_action_index:  3
# break out counter:  40
# current_action_index:  3
# break out counter:  41
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  2
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  3
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  3
# break out counter:  15
# current_action_index:  0
# break out counter:  16
# current_action_index:  2
# break out counter:  17
# current_action_index:  0
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  0
# break out counter:  20
# current_action_index:  2
# break out counter:  21
# current_action_index:  0
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  0
# break out counter:  24
# current_action_index:  2
# break out counter:  25
# current_action_index:  0
# break out counter:  26
# current_action_index:  3
# break out counter:  27
# current_action_index:  0
# break out counter:  28
# current_action_index:  2
# break out counter:  29
# current_action_index:  0
# break out counter:  30
# current_action_index:  3
# break out counter:  31
# current_action_index:  0
# break out counter:  32
# current_action_index:  2
# break out counter:  33
# current_action_index:  0
# break out counter:  34
# current_action_index:  3
# break out counter:  35
# current_action_index:  0
# break out counter:  36
# current_action_index:  2
# break out counter:  37
# current_action_index:  0
# break out counter:  38
# current_action_index:  3
# break out counter:  39
# current_action_index:  0
# break out counter:  40
# current_action_index:  2
# break out counter:  41
# current_action_index:  0
# break out counter:  42
# current_action_index:  3
# break out counter:  43
# current_action_index:  3
# break out counter:  44
# current_action_index:  1
# break out counter:  45
# current_action_index:  1
# break out counter:  46
# current_action_index:  1
# break out counter:  47
# current_action_index:  1
# break out counter:  48
# current_action_index:  1
# break out counter:  49
# current_action_index:  1
# break out counter:  50
# current_action_index:  1
# break out counter:  51
# current_action_index:  1
# break out counter:  52
# current_action_index:  1
# break out counter:  53
# current_action_index:  1
# break out counter:  54
# current_action_index:  1
# break out counter:  55
# current_action_index:  1
# break out counter:  56
# current_action_index:  1
# break out counter:  57
# current_action_index:  0
# break out counter:  58
# current_action_index:  0
# break out counter:  59
# current_action_index:  0
# break out counter:  60
# current_action_index:  0
# break out counter:  61
# current_action_index:  0
# break out counter:  62
# current_action_index:  0
# break out counter:  63
# current_action_index:  0
# break out counter:  64
# current_action_index:  0
# break out counter:  65
# current_action_index:  2
# break out counter:  66
# current_action_index:  3
# break out counter:  1
# current_action_index:  0
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  3
# break out counter:  17
# current_action_index:  3
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  1
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  0
# break out counter:  14
# current_action_index:  0
# break out counter:  15
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  10
# current_action_index:  0
# break out counter:  11
# current_action_index:  0
# break out counter:  12
# current_action_index:  0
# break out counter:  13
# current_action_index:  3
# break out counter:  14
# current_action_index:  2
# break out counter:  15
# current_action_index:  2
# break out counter:  16
# current_action_index:  0
# break out counter:  17
# current_action_index:  2
# break out counter:  18
# current_action_index:  3
# break out counter:  19
# current_action_index:  3
# break out counter:  20
# current_action_index:  3
# break out counter:  21
# current_action_index:  0
# break out counter:  22
# current_action_index:  3
# break out counter:  23
# current_action_index:  3
# break out counter:  24
# current_action_index:  3
# break out counter:  25
# current_action_index:  3
# break out counter:  26
# current_action_index:  3
# break out counter:  27
# current_action_index:  1
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  3
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  3
# break out counter:  7
# current_action_index:  2
# break out counter:  8
# current_action_index:  2
# break out counter:  9
# current_action_index:  2
# break out counter:  10
# current_action_index:  2
# break out counter:  11
# current_action_index:  2
# break out counter:  12
# current_action_index:  2
# break out counter:  13
# current_action_index:  0
# break out counter:  1
# current_action_index:  3
# break out counter:  2
# current_action_index:  3
# break out counter:  3
# current_action_index:  1
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  0
# break out counter:  9
# current_action_index:  0
# break out counter:  1
# current_action_index:  2
# break out counter:  2
# current_action_index:  0
# break out counter:  3
# current_action_index:  0
# break out counter:  4
# current_action_index:  0
# break out counter:  5
# current_action_index:  0
# break out counter:  6
# current_action_index:  0
# break out counter:  7
# current_action_index:  0
# break out counter:  8
# current_action_index:  1
