# %%
""" https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
https://user.ceng.metu.edu.tr/~emre/resources/courses/AdvancedDL_Spring2017/DQN_Muhammed.pdf
https://www.youtube.com/watch?v=NP8pXZdU-5U&t=1s """
import matplotlib.pyplot as plt
import torch
import numpy as np
from copy import deepcopy
from tqdm import tqdm
from SnakeEnvironment import *
from Agent import *
import collections
import random
from itertools import count

import My_lib.SnakeLogic as SL
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# TRY:
# - Longer training
# - More layers in NN
# - Bigger layers in NN
# - Different loss

# %%
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.0
EPS_DECAY = 0.00001
TARGET_UPDATE = 50
MY_SEED = 143
LR = 0.00001
MEMORY_SIZE = 1000000

BLOCK_SIZE = 30
SCREEN_SIZE = 600

state_size = 16
nr_actions = 4

agent_007 = Agent(gamma=GAMMA,exploration_rate=EPS_START,lr=LR,
                  input_size=state_size, batch_size=BATCH_SIZE,
                  nr_actions=nr_actions, max_mem_size=MEMORY_SIZE,
                  nr_consecutive_frames=1, exploration_rate_min=EPS_END,
                  exploration_decay_rate=EPS_DECAY,seed=MY_SEED)

# %%
NUM_EPISODES = 2000

episode_durations = []
episode_rewards = []
episode_exploration_rates = []

t_total_counter = 0
for i_episode in tqdm(range(NUM_EPISODES)):
    # Initialize the environment and state
    game_env = SL.SnakeEnvironment(MY_SEED+i_episode,
                                   SCREEN_SIZE,
                                   BLOCK_SIZE)
    game_env.initialize_environment()

    current_game_score = 0
    current_game_duration = 0

    current_exploration_rate = 0
    current_steps_counter = 0
    game_over = False
    current_state = torch.tensor(game_env.get_state()).reshape(1,-1).to(torch.float32)
    for t in count():
        # Select and perform an action according to greedy epsilon strategy
        action = agent_007.choose_action(current_state)

        # Perform action in game environment and observe reward and new state + termination flag.
        game_env.step(int(action))

        reward = game_env.get_reward()

        game_over = not game_env.get_status()

        new_observation = torch.tensor(game_env.get_state()).reshape(1,-1).to(torch.float32)

        current_game_score += reward
        reward = torch.tensor([reward])

        # Observe new state
        last_state = current_state
        current_state = new_observation

        # Store the transition in memory
        agent_007.store_transition(state=last_state,action=action,
                                   reward=reward,new_state=current_state,
                                   done_flag=game_over)

        # Perform one step of the optimization (on the policy network)
        agent_007.learn()
        if game_over:
            break
        t_total_counter += 1
        current_game_duration += 1

        # Update the target network, copying all weights and biases in DQN from policy to target network
        if t % TARGET_UPDATE == 0:
            agent_007.align_networks()

    episode_rewards.append(current_game_score)
    episode_durations.append(current_game_duration)
    episode_exploration_rates.append(agent_007.exploration_rate)
# Out:
#  85%|████████▌ | 1701/2000 [05:12<00:54,  5.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 48
#      43 agent_007.store_transition(state=last_state,action=action,
#      44                            reward=reward,new_state=current_state,
#      45                            done_flag=game_over)
#      47 # Perform one step of the optimization (on the policy network)
# ---> 48 agent_007.learn()
#      49 if game_over:
#      50     break
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/C++snake/Training/Agent.py:123, in Agent.learn(self)
#     119 """ first beginning learning process when
#     120 non-zero memory is at least batch_size. """
#     121 if self.memory.__len__() >= self.batch_size:
#     122     # Getting memory samples
# --> 123     state_batch, action_batch, reward_batch, new_state_batch, terminal_batch = self.sample_memory()
#     125     # Calculating target Q values
#     126     target_q_values = self.target_network.forward(new_state_batch)
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/C++snake/Training/Agent.py:107, in Agent.sample_memory(self)
#     104 def sample_memory(self) -> tuple[torch.Tensor, ...]:
#     105     """ For collecting all state items in batch in torch tensors (batch_size, nr_channels, height, width)
#     106         and rest in normal 1D tensor."""
# --> 107     random_batch = self.memory.sample(batch_size=self.batch_size)
#     108     grouped_transitions = Transition(*zip(*random_batch))
#     110     state_batch = torch.cat(grouped_transitions.state).to(self.device)
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/C++snake/Training/Agent.py:24, in ReplayMemory.sample(self, batch_size)
#      23 def sample(self, batch_size: int) -> list[Transition, ...]:
# ---> 24     return random.sample(self.memory, batch_size)
#
# File ~/miniforge3/lib/python3.10/random.py:503, in Random.sample(self, population, k, counts)
#     501             j = randbelow(n)
#     502         selected_add(j)
# --> 503         result[i] = population[j]
#     504 return result
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot([i for i in range(len(episode_rewards))], episode_rewards)
ax[1].plot([i for i in range(len(episode_durations))], episode_durations)
ax[2].plot([i for i in range(len(episode_exploration_rates))], episode_exploration_rates)
plt.show()

# %%
avg_period = NUM_EPISODES//100
avg_episode_rewards, avg_episode_durations, avg_episode_exploration_rates = [], [], []
for period in range(0, len(episode_rewards) // avg_period):
    avg_episode_rewards.append(np.mean(episode_rewards[avg_period * period : avg_period * (period + 1)]))
    avg_episode_durations.append(np.mean(episode_durations[avg_period * period : avg_period * (period + 1)]))
    avg_episode_exploration_rates.append(np.mean(episode_exploration_rates[avg_period * period : avg_period * (period + 1)]))

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot([ i for i in range(len(avg_episode_rewards))], avg_episode_rewards)
ax[1].plot([ i for i in range(len(avg_episode_durations))], avg_episode_durations)
ax[2].plot([ i for i in range(len(avg_episode_exploration_rates))], avg_episode_exploration_rates)
plt.show()

# %%
Play_game = True
if Play_game:
    game_env = SnakeEnvironment(seed=1,  # Try both constant seed and varying seed for each episode
                                neural_net=agent_007.policy_network,
                                display_gameplay=True,
                                graphics_speed=6)
    game_env.run()

# %%
for t in tqdm(range(100,200)):
    game_env = SnakeEnvironment(seed=t,  # Try both constant seed and varying seed for each episode
                                neural_net=agent_007.policy_network,
                                display_gameplay=False,
                                graphics_speed=100)
    game_env.run()
    if game_env.current_score > 65:
        print("seed: ", t, "score: ", game_env.current_score)
# Out:
#  48%|████▊     | 48/100 [00:02<00:02, 17.70it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [27], line 6
#       1 for t in tqdm(range(100,200)):
#       2     game_env = SnakeEnvironment(seed=t,  # Try both constant seed and varying seed for each episode
#       3                                 neural_net=agent_007.policy_network,
#       4                                 display_gameplay=False,
#       5                                 graphics_speed=100)
# ----> 6     game_env.run()
#       7     if game_env.current_score > 65:
#       8         print("seed: ", t, "score: ", game_env.current_score)
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/DQN4 - new snake impl-fixed_state_bug/SnakeEnvironment.py:213, in SnakeEnvironment.run(self)
#     211             self._update_direction(event=_event)
#     212 else:
# --> 213     current_action_index = torch.argmax(input=self.neural_net.forward(self.get_state())).item()
#     214     self._update_direction(direction=current_action_index)
#     216 # Updating snake state
#
# File ~/Library/CloudStorage/OneDrive-AarhusUniversitet/Div. Github projekter/Snake/DQN4 - new snake impl-fixed_state_bug/SnakeEnvironment.py:196, in SnakeEnvironment.get_state(self)
#     193 _direction_state = [0, 0, 0, 0]
#     194 _direction_state[int_2_direction[self.snake.get_direction()]] = 1
# --> 196 return torch.tensor(_wall_danger_state + _snake_danger_state + _apple_state + _direction_state, dtype=torch.float32).reshape(1, -1)
#
# KeyboardInterrupt:

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c = [9,10,11,12]
d = [13,14,15,16]
torch.tensor(a+b+c+d,dtype=torch.float32).reshape(1,-1).shape
# Out:
# torch.Size([1, 16])
